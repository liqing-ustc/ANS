# %%
import json

splits = ['train', 'val', 'test']
split2dataset = {}
for split in splits:
    split2dataset[split] = json.load(open('expr_%s.json'%split))

# %%
def render_img(img_paths):
    images = [Image.open(symbol_images_dir + x) for x in img_paths]
    widths, heights = zip(*(i.size for i in images))

    total_width = sum(widths)
    max_height = max(heights)

    new_im = Image.new('RGB', (total_width, max_height))

    x_offset = 0
    for im in images:
        new_im.paste(im, (x_offset,0))
        x_offset += im.size[0]
    return new_im
# Out:
# [{'id': 'val_00004897',
#   'img_paths': ['7/exp28837.jpg',
#    'div/div_38271.jpg',
#    '4/exp23726.jpg',
#    '+/+_74372.jpg',
#    '(/exp48159.jpg',
#    '4/exp2034.jpg',
#    'times/times_41887.jpg',
#    '0/exp80004.jpg',
#    'times/exp52403.jpg',
#    '2/exp53000.jpg',
#    '-/exp11534.jpg',
#    '(/exp61821.jpg',
#    '2/exp93685.jpg',
#    '+/exp8588.jpg',
#    '(/exp34940.jpg',
#    '8/exp70748.jpg',
#    '+/exp24105.jpg',
#    '8/exp59064.jpg',
#    ')/exp34022.jpg',
#    '+/exp10021.jpg',
#    '(/(_28212.jpg',
#    '(/exp26090.jpg',
#    '0/exp18321.jpg',
#    '-/-_30840.jpg',
#    '7/exp1166.jpg',
#    ')/exp140.jpg',
#    'div/exp52332.jpg',
#    '5/5_61810.jpg',
#    '+/exp31868.jpg',
#    '9/exp52433.jpg',
#    ')/)_108725.jpg',
#    ')/exp57071.jpg',
#    ')/exp2645.jpg',
#    '+/exp31.jpg',
#    '4/4_49183.jpg',
#    'times/times_6837.jpg',
#    '(/(_75165.jpg',
#    '2/exp52822.jpg',
#    'times/exp88452.jpg',
#    '(/(_63880.jpg',
#    '7/7_91924.jpg',
#    'times/exp55595.jpg',
#    '7/7_54528.jpg',
#    ')/)_91966.jpg',
#    'times/exp17511.jpg',
#    '4/exp3716.jpg',
#    '-/-_20370.jpg',
#    '(/(_20343.jpg',
#    '0/exp41932.jpg',
#    '-/exp69225.jpg',
#    '6/exp55891.jpg',
#    'div/exp1779.jpg',
#    '2/exp2233.jpg',
#    ')/)_48080.jpg',
#    'times/exp71783.jpg',
#    '2/exp34440.jpg',
#    ')/exp2110.jpg'],
#   'expr': '7/4+(4*0*2-(2+(8+8)+((0-7)/5+9)))+4*(2*(7*7)*4-(0-6/2)*2)',
#   'head': [1,
#    3,
#    1,
#    33,
#    10,
#    6,
#    8,
#    6,
#    10,
#    8,
#    3,
#    19,
#    13,
#    19,
#    16,
#    16,
#    13,
#    16,
#    16,
#    10,
#    28,
#    23,
#    23,
#    26,
#    23,
#    23,
#    28,
#    26,
#    19,
#    28,
#    28,
#    19,
#    10,
#    -1,
#    35,
#    33,
#    46,
#    38,
#    44,
#    41,
#    41,
#    38,
#    41,
#    41,
#    46,
#    44,
#    35,
#    49,
#    49,
#    54,
#    51,
#    49,
#    51,
#    49,
#    46,
#    54,
#    46],
#   'res': 1570,
#   'res_all': [7,
#    2,
#    4,
#    2,
#    None,
#    4,
#    0,
#    0,
#    0,
#    2,
#    0,
#    None,
#    2,
#    18,
#    None,
#    8,
#    16,
#    8,
#    None,
#    27,
#    None,
#    None,
#    0,
#    0,
#    7,
#    None,
#    0,
#    5,
#    9,
#    9,
#    None,
#    None,
#    None,
#    1570,
#    4,
#    1568,
#    None,
#    2,
#    98,
#    None,
#    7,
#    49,
#    7,
#    None,
#    392,
#    4,
#    392,
#    None,
#    0,
#    0,
#    6,
#    3,
#    2,
#    None,
#    0,
#    2,
#    None],
#   'eval': 5},
#  {'id': 'val_00004898',
#   'img_paths': ['6/6_2330.jpg',
#    'times/exp45896.jpg',
#    '(/(_23747.jpg',
#    '6/6_64326.jpg',
#    'times/exp5816.jpg',
#    '(/exp41594.jpg',
#    '1/exp72604.jpg',
#    'times/exp51321.jpg',
#    '(/(_108577.jpg',
#    '5/5_100702.jpg',
#    'times/exp12142.jpg',
#    '1/exp74575.jpg',
#    ')/)_66704.jpg',
#    ')/exp28276.jpg',
#    '-/exp66017.jpg',
#    '0/0_19072.jpg',
#    'times/exp62848.jpg',
#    '(/(_69929.jpg',
#    '(/(_58041.jpg',
#    '9/exp83487.jpg',
#    '+/+_73569.jpg',
#    '2/exp54673.jpg',
#    '+/exp22278.jpg',
#    '4/exp44097.jpg',
#    ')/exp32822.jpg',
#    'times/times_7580.jpg',
#    '2/exp18685.jpg',
#    ')/exp16867.jpg',
#    ')/exp81378.jpg',
#    '-/exp9366.jpg',
#    '(/exp595.jpg',
#    '1/1_39456.jpg',
#    'div/exp61708.jpg',
#    '8/exp94532.jpg',
#    'times/exp20844.jpg',
#    '(/exp40071.jpg',
#    '6/exp1447.jpg',
#    '-/exp71073.jpg',
#    '6/exp55185.jpg',
#    'times/exp4648.jpg',
#    '3/exp78095.jpg',
#    ')/exp101852.jpg',
#    '-/exp30728.jpg',
#    '8/8_48919.jpg',
#    '+/exp13657.jpg',
#    '(/(_61542.jpg',
#    '4/4_34996.jpg',
#    '+/exp78991.jpg',
#    '1/exp10823.jpg',
#    'times/exp4028.jpg',
#    '5/5_1760.jpg',
#    ')/)_93763.jpg',
#    ')/exp74620.jpg',
#    'times/exp1896.jpg',
#    '(/(_83548.jpg',
#    '7/7_42943.jpg',
#    '+/exp94796.jpg',
#    '5/exp43942.jpg',
#    ')/exp753.jpg'],
#   'expr': '6*(6*(1*(5*1))-0*((9+2+4)*2))-(1/8*(6-6*3)-8+(4+1*5))*(7+5)',
#   'head': [1,
#    29,
#    14,
#    4,
#    14,
#    7,
#    7,
#    4,
#    10,
#    10,
#    7,
#    10,
#    10,
#    7,
#    1,
#    16,
#    14,
#    25,
#    22,
#    20,
#    22,
#    20,
#    25,
#    22,
#    22,
#    16,
#    25,
#    25,
#    14,
#    -1,
#    44,
#    32,
#    34,
#    32,
#    42,
#    37,
#    37,
#    34,
#    39,
#    37,
#    39,
#    37,
#    44,
#    42,
#    53,
#    47,
#    47,
#    44,
#    49,
#    47,
#    49,
#    47,
#    44,
#    29,
#    56,
#    56,
#    53,
#    56,
#    56],
#   'res': 72,
#   'res_all': [6,
#    180,
#    None,
#    6,
#    30,
#    None,
#    1,
#    5,
#    None,
#    5,
#    5,
#    1,
#    None,
#    None,
#    30,
#    0,
#    0,
#    None,
#    None,
#    9,
#    11,
#    2,
#    15,
#    4,
#    None,
#    30,
#    2,
#    None,
#    None,
#    72,
#    None,
#    1,
#    1,
#    8,
#    0,
#    None,
#    6,
#    0,
#    6,
#    18,
#    3,
#    None,
#    0,
#    8,
#    9,
#    None,
#    4,
#    9,
#    1,
#    5,
#    5,
#    None,
#    None,
#    108,
#    None,
#    7,
#    12,
#    5,
#    None],
#   'eval': 5},
#  {'id': 'val_00004899',
#   'img_paths': ['6/exp83409.jpg',
#    'div/exp40764.jpg',
#    '3/exp40455.jpg',
#    'times/exp53278.jpg',
#    '(/(_28040.jpg',
#    '8/exp11389.jpg',
#    '+/exp15984.jpg',
#    '(/exp47966.jpg',
#    '3/3_3451.jpg',
#    '+/exp89257.jpg',
#    '2/exp17067.jpg',
#    ')/exp52878.jpg',
#    '+/exp45182.jpg',
#    '(/(_61400.jpg',
#    '5/exp40737.jpg',
#    'times/exp60162.jpg',
#    '2/exp30922.jpg',
#    'div/exp37923.jpg',
#    '2/exp2788.jpg',
#    'times/exp3282.jpg',
#    '7/exp1559.jpg',
#    '-/-_98852.jpg',
#    '7/exp50157.jpg',
#    'times/exp44015.jpg',
#    '(/exp34525.jpg',
#    '8/8_21555.jpg',
#    '-/exp24117.jpg',
#    '1/exp84085.jpg',
#    ')/exp98019.jpg',
#    'times/exp27472.jpg',
#    '(/exp56080.jpg',
#    '7/7_38442.jpg',
#    'div/exp59499.jpg',
#    '7/exp39595.jpg',
#    'div/exp57013.jpg',
#    '(/(_95529.jpg',
#    '8/exp96243.jpg',
#    'times/exp408.jpg',
#    '1/exp11284.jpg',
#    ')/)_109660.jpg',
#    '-/exp87154.jpg',
#    '(/exp6607.jpg',
#    '8/8_461.jpg',
#    '+/exp72453.jpg',
#    '(/exp30905.jpg',
#    '5/exp79449.jpg',
#    '+/exp22390.jpg',
#    '8/8_59641.jpg',
#    ')/)_109278.jpg',
#    ')/exp29431.jpg',
#    'div/exp59739.jpg',
#    '1/exp92481.jpg',
#    '+/exp10575.jpg',
#    '3/3_43269.jpg',
#    ')/exp21236.jpg',
#    ')/exp18437.jpg',
#    ')/exp82069.jpg'],
#   'expr': '6/3*(8+(3+2)+(5*2/2*7-7*(8-1)*(7/7/(8*1)-(8+(5+8))/1+3)))',
#   'head': [1,
#    3,
#    1,
#    -1,
#    12,
#    6,
#    12,
#    9,
#    9,
#    6,
#    9,
#    9,
#    3,
#    21,
#    15,
#    17,
#    15,
#    19,
#    17,
#    21,
#    19,
#    12,
#    23,
#    29,
#    26,
#    26,
#    23,
#    26,
#    26,
#    21,
#    52,
#    32,
#    34,
#    32,
#    40,
#    37,
#    37,
#    34,
#    37,
#    37,
#    52,
#    43,
#    43,
#    50,
#    46,
#    46,
#    43,
#    46,
#    46,
#    43,
#    40,
#    50,
#    29,
#    52,
#    52,
#    21,
#    12],
#   'res': 26,
#   'res_all': [6,
#    2,
#    3,
#    26,
#    None,
#    8,
#    13,
#    None,
#    3,
#    5,
#    2,
#    None,
#    13,
#    None,
#    5,
#    10,
#    2,
#    5,
#    2,
#    35,
#    7,
#    0,
#    7,
#    49,
#    None,
#    8,
#    7,
#    1,
#    None,
#    147,
#    None,
#    7,
#    1,
#    7,
#    1,
#    None,
#    8,
#    8,
#    1,
#    None,
#    0,
#    None,
#    8,
#    21,
#    None,
#    5,
#    13,
#    8,
#    None,
#    None,
#    21,
#    1,
#    3,
#    3,
#    None,
#    None,
#    None],
#   'eval': 5}]
